# %%
import pandas as pd

data1 = pd.read_csv('authentic_cs_1.csv')
data2 = pd.read_csv('authentic_cs_2.csv')
data3 = pd.read_csv('authentic_cs_3.csv')

data1['date'] = pd.to_datetime(data1['date'], format='%Y-%m-%d')
data2['date'] = pd.to_datetime(data1['date'], format='%Y-%m-%d')
data3['date'] = pd.to_datetime(data1['date'], format='%Y-%m-%d')

#1#############
print("1#阳")
data19_detail = data1.loc[data1['date'].between(pd.to_datetime('2019-01-01'),pd.to_datetime('2019-12-31'))]
print('2019\n')
print((data19_detail['time_diff'].describe()).round(2))

data20_detail = data1.loc[data1['date'].between(pd.to_datetime('2020-01-01'),pd.to_datetime('2020-12-31'))]
print('2020\n')
print((data20_detail['time_diff'].describe()).round(2))

data21_detail = data1.loc[data1['date'].between(pd.to_datetime('2021-01-01'),pd.to_datetime('2021-12-31'))]
print('2021\n')
print((data21_detail['time_diff'].describe()).round(2))

data22_detail = data1.loc[data1['date'].between(pd.to_datetime('2022-01-01'),pd.to_datetime('2022-12-31'))]
print('2022\n')
print((data22_detail['time_diff'].describe()).round(2))


#2#############
print("2#阳")
data19_detail = data2.loc[data2['date'].between(pd.to_datetime('2019-01-01'),pd.to_datetime('2019-12-31'))]
print('2019\n')
print((data19_detail['time_diff'].describe()).round(2))

data20_detail = data2.loc[data2['date'].between(pd.to_datetime('2020-01-01'),pd.to_datetime('2020-12-31'))]
print('2020\n')
print((data20_detail['time_diff'].describe()).round(2))

data21_detail = data2.loc[data2['date'].between(pd.to_datetime('2021-01-01'),pd.to_datetime('2021-12-31'))]
print('2021\n')
print((data21_detail['time_diff'].describe()).round(2))

data22_detail = data2.loc[data2['date'].between(pd.to_datetime('2022-01-01'),pd.to_datetime('2022-12-31'))]
print('2022\n')
print((data22_detail['time_diff'].describe()).round(2))

#3#############
print("3#阳")
data19_detail = data3.loc[data3['date'].between(pd.to_datetime('2019-01-01'),pd.to_datetime('2019-12-31'))]
print('2019\n')
print((data19_detail['time_diff'].describe()).round(2))

data20_detail = data3.loc[data3['date'].between(pd.to_datetime('2020-01-01'),pd.to_datetime('2020-12-31'))]
print('2020\n')
print((data20_detail['time_diff'].describe()).round(2))

data21_detail = data3.loc[data3['date'].between(pd.to_datetime('2021-01-01'),pd.to_datetime('2021-12-31'))]
print('2021\n')
print((data21_detail['time_diff'].describe()).round(2))

data22_detail = data3.loc[data3['date'].between(pd.to_datetime('2022-01-01'),pd.to_datetime('2022-12-31'))]
print('2022\n')
print((data22_detail['time_diff'].describe()).round(2))
# Out:
# 1#阳
# 2019
#
# count    212.00
# mean      25.08
# std       11.62
# min        6.50
# 25%       15.84
# 50%       22.00
# 75%       33.82
# max       49.95
# Name: time_diff, dtype: float64
# 2020
#
# count    83.00
# mean     35.03
# std      10.62
# min       7.98
# 25%      29.78
# 50%      37.97
# 75%      42.82
# max      49.67
# Name: time_diff, dtype: float64
# 2021
#
# count    182.00
# mean      31.61
# std       10.36
# min        7.92
# 25%       23.44
# 50%       32.97
# 75%       39.71
# max       49.87
# Name: time_diff, dtype: float64
# 2022
#
# count    221.00
# mean      29.59
# std        8.67
# min        6.83
# 25%       23.28
# 50%       30.42
# 75%       35.72
# max       49.83
# Name: time_diff, dtype: float64
# 2#阳
# 2019
#
# count    212.00
# mean      28.22
# std       11.95
# min        7.07
# 25%       18.31
# 50%       24.88
# 75%       38.71
# max       49.63
# Name: time_diff, dtype: float64
# 2020
#
# count    83.00
# mean     32.77
# std       8.38
# ...
